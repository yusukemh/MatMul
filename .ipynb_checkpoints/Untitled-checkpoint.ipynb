# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# runtime comparison using average running times
fox = np.array([1.5539798, 0.3346818, 0.0590878, 0.0286738, 0.0326626, 0.0590672])
cannon = np.array([1.4635436, 0.2566136, 0.0531246, 0.0204924, 0.0197286, 0.0229716])
outer = np.array([1.4757056, 0.265138, 0.054216, 0.0356182, 0.0460436, 0.0965112])

fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=400)
num_procs = [1, 4, 16, 64, 100, 400]
line_3 = ax.plot(num_procs, outer, label="outer", c='b')
line_1 = ax.plot(num_procs, fox, label="fox", c='y')
line_2 = ax.plot(num_procs, cannon, label="cannon", c='r')
ax.set_title("Runtime on a realistic platform", fontsize=20)
ax.legend(fontsize=15)
ax.set_xlabel("# of processors", fontsize=20)
ax.set_ylabel("Runtime (sec)", fontsize=20)
ax.set_yscale('log')
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("plots/1.png", bbox_inches = 'tight')

# %%
# parallel speedup using speedup on average running times
# fox = np.array([1, 4.6431559, 26.299503, 54.195111, 47.576733, 26.308675])
# cannon = np.array([1, 5.7032971, 27.549263, 71.418847, 74.183854, 63.710999])
# outer = np.array([1, 5.5658019, 27.219005, 41.431223, 32.050178, 15.290511])

fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=400)
num_procs = [1, 4, 16, 64, 100, 400]

lie_0 = ax.plot(x, x, label='linear', c='k')
line_3 = ax.plot(num_procs, outer[0]/outer, label='outer', c='b')
line_1 = ax.plot(num_procs, fox[0]/fox, label='fox', c='y')
line_2 = ax.plot(num_procs, cannon[0]/cannon, label='cannon', c='r')
ax.set_title("Parallel Speedup on a realistic platform", fontsize=20)
ax.legend(fontsize=15)
ax.set_xlabel("# of processors", fontsize=20)
ax.set_ylabel("Parallel Speedup", fontsize=20)
ax.set_yscale('log')
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("plots/2.png", bbox_inches = 'tight')

# %% [markdown]
# ## Ideal platform

# %%
# runtime comparison using average running times
fox = np.array([1.5663204, 0.2896692, 0.0455754, 0.0100914, 0.0070782, 0.001998])
cannon = np.array([1.5775902, 0.2753608, 0.0458754, 0.0111368, 0.0073162, 0.0021388])
outer = np.array([1.5331018, 0.2617222, 0.0481732, 0.0117802, 0.0069656, 0.0021104])

fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=400)
num_procs = [1, 4, 16, 64, 100, 400]
line_3 = ax.plot(num_procs, outer, label="outer")
line_1 = ax.plot(num_procs, fox, label="fox")
line_2 = ax.plot(num_procs, cannon, label="cannon")
ax.set_title("Runtime on an ideal platform", fontsize=20)
ax.legend(fontsize=15)
ax.set_xlabel("# of processors", fontsize=20)
ax.set_ylabel("Runtime (sec)", fontsize=20)
ax.set_yscale('log')
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("plots/3.png", bbox_inches = 'tight')

# %%
# parallel speedup using speedup on average running times
# fox = np.array([1.520859, 0.291641, 0.056872, 0.010793, 0.007366, 0.002057])
# cannon = np.array([1.559107, 0.267810, 0.049169, 0.010768, 0.007724, 0.002109])
# outer = np.array([1.549234, 0.228641, 0.038322, 0.010039, 0.006418, 0.001971])

fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=400)
num_procs = [1, 4, 16, 64, 100, 400]

lie_0 = ax.plot(x, x, label='linear', c='k')
line_3 = ax.plot(num_procs, outer[0]/outer, label='outer', c='b')
line_1 = ax.plot(num_procs, fox[0]/fox, label='fox', c='y')
line_2 = ax.plot(num_procs, cannon[0]/cannon, label='cannon', c='r')
ax.set_title("Parallel Speedup on an ideal platform", fontsize=20)
ax.legend(fontsize=15)
ax.set_xlabel("# of processors", fontsize=20)
ax.set_ylabel("Parallel Speedup", fontsize=20)
ax.set_yscale('log')
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("plots/4.png", bbox_inches = 'tight')

# %% [markdown]
# ## No computation

# %%
num_procs = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
outer = np.array([0.0030894, 0.0235766, 0.0792374, 0.1876458, 0.3664038, 0.6330116, 1.0051316, 1.5003174])
cannon = np.array([0.0053936, 0.0321614, 0.0982386, 0.2198098, 0.4131046, 0.6965272, 1.0946648, 1.620751])
fox = np.array([0.004228, 0.0266884, 0.0862824, 0.1993944, 0.385249, 0.6597118, 1.0389034, 1.542063])


fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=16000)
line_3 = ax.plot(num_procs, outer, label="outer", c='b')
line_1 = ax.plot(num_procs, fox, label="fox", c='y')
line_2 = ax.plot(num_procs, cannon, label="cannon", c='r')
ax.set_title("Runntime with 100 processors on an ideal platform", fontsize=15)
ax.legend(fontsize=15)
ax.set_xlabel("Matrix size", fontsize=20)
ax.set_ylabel("Runnint time (sec)", fontsize=20)
ax.set_yscale('log')
# ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("5.png", bbox_inches = 'tight')

# %%
num_procs = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
one_proc_fox = np.array([0.291864, 2.333384, 7.873656, 18.661919, 36.447687, 62.974508, 99.998656, 149.269997])
one_proc_outer = np.array([0.293000, 2.344000, 7.911000, 18.752000, 36.625000, 63.288000, 100.499000, 150.016000])
one_proc_cannon = np.array([0.290140, 2.318718, 7.821842, 18.538840, 36.206067, 62.554975, 99.327563, 148.266811])


fig, ax = plt.subplots(1)
x = np.linspace(start=1000, stop=8000)

lie_0 = ax.plot(x, np.ones(len(x)) * 100, label='linear', c='k')
line_3 = ax.plot(num_procs, one_proc_outer/outer, label='outer', c='b')
line_1 = ax.plot(num_procs, one_proc_fox/fox, label='fox', c='y')
line_2 = ax.plot(num_procs, one_proc_cannon/cannon, label='cannon', c='r')
ax.set_title("Parallel Speedup on an ideal platform", fontsize=15)
ax.legend(fontsize=10)
ax.set_xlabel("Matrix size", fontsize=20)
ax.set_ylabel("Parallel Speedup", fontsize=20)
# ax.set_yscale('log')
# ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("6.png", bbox_inches = 'tight')

# %% [markdown]
# ## no computation, realistic

# %%
num_procs = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
outer = np.array([0.04148  , 0.0653032, 0.1264252, 0.242439 , 0.4309702, 0.7095792, 1.0958352, 1.6073336])
cannon = np.array([0.0169142, 0.0450392, 0.1135574, 0.2373396, 0.435839 , 0.7237048, 1.1227402, 1.6605548])
fox = np.array([0.0281938, 0.0531872, 0.1145772, 0.2318444, 0.4213642, 0.7037354, 1.0947662, 1.6085226])


fig, ax = plt.subplots(1)
x = np.linspace(start=1, stop=16000)
line_3 = ax.plot(num_procs, outer, label="outer", c='b')
line_1 = ax.plot(num_procs, fox, label="fox", c='y')
line_2 = ax.plot(num_procs, cannon, label="cannon", c='r')
ax.set_title("Runntime with 100 processors on an realistic platform", fontsize=15)
ax.legend(fontsize=15)
ax.set_xlabel("Matrix size", fontsize=20)
ax.set_ylabel("Runnint time (sec)", fontsize=20)
ax.set_yscale('log')
# ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("5.png", bbox_inches = 'tight')

# %%
num_procs = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
one_proc_fox = np.array([0.291864, 2.333384, 7.873656, 18.661919, 36.447687, 62.974508, 99.998656, 149.269997])
one_proc_outer = np.array([0.293000, 2.344000, 7.911000, 18.752000, 36.625000, 63.288000, 100.499000, 150.016000])
one_proc_cannon = np.array([0.290140, 2.318718, 7.821842, 18.538840, 36.206067, 62.554975, 99.327563, 148.266811])


fig, ax = plt.subplots(1)
x = np.linspace(start=1000, stop=8000)

lie_0 = ax.plot(x, np.ones(len(x)) * 100, label='linear', c='k')
line_3 = ax.plot(num_procs, one_proc_outer/outer, label='outer', c='b')
line_1 = ax.plot(num_procs, one_proc_fox/fox, label='fox', c='y')
line_2 = ax.plot(num_procs, one_proc_cannon/cannon, label='cannon', c='r')
ax.set_title("Parallel Speedup on an realistic platform", fontsize=15)
ax.legend(fontsize=10)
ax.set_xlabel("Matrix size", fontsize=20)
ax.set_ylabel("Parallel Speedup", fontsize=20)
# ax.set_yscale('log')
# ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=15)
fig.savefig("6.png", bbox_inches = 'tight')

# %%
m_fox = np.array([
    [0.027863, 0.052891, 0.112639, 0.233493, 0.420726, 0.708922, 1.093608, 1.605271],
    [0.027732, 0.052713, 0.114781, 0.231019, 0.418192, 0.698375, 1.094319, 1.613316],
    [0.028396, 0.052975, 0.115665, 0.229803, 0.424896, 0.707613, 1.092715, 1.612238],
    [0.028482, 0.053216, 0.115880, 0.231117, 0.417872, 0.700543, 1.096331, 1.594472],
    [0.028496, 0.054141, 0.113921, 0.233790, 0.425135, 0.703224, 1.096858, 1.617316],
])
m_cannon = np.array([
    [0.015407, 0.043899, 0.116813, 0.236780, 0.435732, 0.723470, 1.116577, 1.651665],
    [0.017828, 0.044111, 0.112610, 0.237203, 0.436034, 0.722230, 1.128846, 1.661712],
    [0.016427, 0.046535, 0.112523, 0.237317, 0.435578, 0.725743, 1.118235, 1.664092],
    [0.017620, 0.044431, 0.112967, 0.237760, 0.435695, 0.723913, 1.126161, 1.667782],
    [0.017289, 0.046220, 0.112874, 0.237638, 0.436156, 0.723168, 1.123882, 1.657523],
])
m_outer = np.array([
    [0.041476, 0.065311, 0.126433, 0.242447, 0.430960, 0.709580, 1.095825, 1.607329],
    [0.041469, 0.065299, 0.126439, 0.242442, 0.430986, 0.709618, 1.095852, 1.607334],
    [0.041481, 0.065290, 0.126426, 0.242443, 0.430971, 0.709568, 1.095840, 1.607347],
    [0.041505, 0.065321, 0.126423, 0.242433, 0.430974, 0.709571, 1.095836, 1.607333],
    [0.041469, 0.065295, 0.126405, 0.242430, 0.430960, 0.709559, 1.095823, 1.607325],
])

# %%
np.mean(m_fox, axis = 0),np.mean(m_cannon, axis = 0), np.mean(m_outer, axis = 0)
# Out:
# (array([0.0281938, 0.0531872, 0.1145772, 0.2318444, 0.4213642, 0.7037354,
#         1.0947662, 1.6085226]),
#  array([0.0169142, 0.0450392, 0.1135574, 0.2373396, 0.435839 , 0.7237048,
#         1.1227402, 1.6605548]),
#  array([0.04148  , 0.0653032, 0.1264252, 0.242439 , 0.4309702, 0.7095792,
#         1.0958352, 1.6073336]))
